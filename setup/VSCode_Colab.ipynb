# %% [markdown]
# # Clone Repository on Colab

# %%
# OBUTraffic_Encoder_Decoder Setup
# !git clone https://{name}:{password}@github.com/giobbu/traffic_enc_dec
# %env PYTHONPATH=.:$PYTHONPATH
# %cd traffic_enc_dec/development
# %ls
# Out:
# Cloning into 'enc_dec'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 175 (delta 88), reused 136 (delta 49), pack-reused 0
# Receiving objects: 100% (175/175), 36.38 MiB | 19.67 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# env: PYTHONPATH=.:$PYTHONPATH
# enc_dec/  sample_data/

# %% [markdown]
# # VSCode on Colab

# %%
# !curl -fsSL https://code-server.dev/install.sh | sh
# !pip install -qqq pyngrok

from pyngrok import ngrok
url = ngrok.connect(port=80)
print(url)
# Out:
# NgrokTunnel: "http://4206eccea59c.ngrok.io" -> "http://localhost:80"

# %%
# !nohup code-server --port 80 --auth none &
# Out:
# nohup: appending output to 'nohup.out'
